# %%
class bank:
    pin=1234
    balance=20000
    def message(self):
        print("Welcome to SBI")
        
        
class authorise(bank):
    upin=int(input("Enter Your Pin : "))
    if(upin==pin):
        #call menu option
    else:
        count=1
        while(count<3):
            count=count+1
            upin=int(input("Enter Your Pin : "))
            if(upin==pin):
                #call menu option
        else:
            print("Card Blocked")
            
class balance(bank):
    def operations(self):
        print("Your Current Balance is Rs.",balance)
        
class deposit(bank):
    def operations(self):
        amount=int(input("Enter amount to deposit : "))
        balance=balance+amount
        print("Current balance is Rs.",balance)
        
class withdraw(bank):
    def operations(self):
        amount=int(input("Enter amount to deposit : "))
        balance=balance-amount
        print("Current balance is Rs.",balance)

            
class menu(bank):
    def operations(self):
        print()
    
class handler:   
    def manage(obj):
        obj.operations()
        
b=balance()
d=deposit()
w=withdraw()
m=menu()
h=handler()
h.manage(b)
h.manage(d)
h.manage(w)
# Out:
#   File "<ipython-input-2-5116c06a8a5c>", line 12
#     else:
#     ^
# IndentationError: expected an indented block

# %%
class bank:
    B.mybank(self)
    def mybank(self):
        print("Welcome to SBI")
        upin=int(input("Enter Yor Pin : "))
        #call Authenticate
        a=authenticate()
        a.auth(pin)
B=bank()      
class authenticate:
    pin=1234
    def auth(self,pin):
        if(upin==pin):
            #call menu option
            m=menu()
            m.mymenu()
        else:
            count=1
            while(count<3):
                count=count+1
                upin=int(input("Enter Your Pin : "))
                if(upin==pin):
                    #call menu option
                    m=menu()
                    m.mymenu()
            else:
                print("Card Blocked")
                
class menu:
    def mymenu(self):
        print("Press 1 for Deposit")
        print("Press 2 for Withdraw")        
        print("Press 3 to Check Balance")
        opt=(int(input("Select option : "))
        if(opt==1)
             #call Deposit
             d=deposit()
             d.depot(opt)
        elif(opt==2):
             #call Withdraw
             w=withdraw()
             w.with(opt)
             
        elif(opt==3):
             #call Balance
             b=balance()
             b.updateBalance(opt)
             
class deposit:
    def depot(self,opt):
        amt=int(input("Enter amount to deposit"))
        #call balance
        bal=balance()
        bal.mybalance(opt,amt)
             
class withdraw:
    def with(self,opt):
        amt=int(input("Enter amount to Withsdraw"))
        #call Balance
        bal=balance()
        bal.mybalance(opt,amt)
             
class balance:
    initialBalance=10000
    def updateBalance(self,opt,amt):
        if(opt==1):
             initialBalance=initialBalance+amt
             print("Current Balance : ",initialBalance)
        elif(opt==2):
             initialBalance=initialBalance-amt
             print("Current Balance : ",initialBalance)
        elif(opt==3):
             print("Current Balance : ",initialBalance)
# Out:
#   File "<ipython-input-7-b6d68de94a43>", line 37
#     d=deposit()
#     ^
# SyntaxError: invalid syntax

# %%
class Bank:
    def __init__(self):
        self.balance=10000
        print("Welcome to SBI")
        authentication()
class authentication:
    pin=1234
    upin=int(input("Enter PIN : "))
    def auth(pin):
        if(upin==pin):
            print("correct pin")
Bank()
authentication()
a.auth(pin)
